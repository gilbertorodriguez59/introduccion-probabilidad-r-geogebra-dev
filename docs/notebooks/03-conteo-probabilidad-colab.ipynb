# %% [markdown]
# # Capítulo 3. Técnicas de conteo y enumeración
# Cuaderno en R para factoriales, arreglos, combinaciones y enumeración sistemática.

# %%
n <- 8; r <- 3
factorial(n)
factorial(n)/factorial(n-r)
choose(n,r)

# %%
combn(1:6, 3)
expand.grid(A=1:3, B=1:4)
